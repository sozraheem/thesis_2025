# %% [markdown]
# ## General notebook for all patients

# %%
# imports
import mne
import warnings
from utils.run_patient import run_patient_simulation

# utils functions
#from utils.online_simulation import online_simulation, online_adaptation_simulation_sw

# Turn off warnings (that most likely occur from ToeplitzLDA)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)
mne.set_log_level('WARNING')

# %% [markdown]
# ### New function

# %%
perf = run_patient_simulation(patient=7, last_session_nr=5, calibration_selection="6D_long_350", include_offline_performance=True)
