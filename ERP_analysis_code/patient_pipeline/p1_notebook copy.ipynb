# %% [markdown]
# # Patient 1

# %% [markdown]
# In this jupyter notebook the data of patient 1 is loaded, inspected and processed.

# %%
# imports
import pickle
import mne
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import warnings
from toeplitzlda.classification import ToeplitzLDA

# utils functions
from utils.preprocessing import load_session_chached, merge_sessions
from utils.online_simulation import online_simulation
from utils.feature_extraction import load_features_chached_v2
#from utils.feature_extraction import load_features_chached
from utils.run_patient import run_patient_online_sessions
from results.results_functions import extract_ews, extract_tws

# Turn off warnings (that most likely occur from ToeplitzLDA)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)
mne.set_log_level('WARNING')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 15
#      13 from utils.feature_extraction import load_features_chached_v2
#      14 #from utils.feature_extraction import load_features_chached
# ---> 15 from utils.run_patient import run_patient_online_sessions
#      16 from results.results_functions import extract_ews, extract_tws
#      18 # Turn off warnings (that most likely occur from ToeplitzLDA)
#
# File c:\Users\Soz\OneDrive - Radboud Universiteit\Bureaublad\BSc_Thesis\Code\BSc_Thesis_Project\ERP_analysis_code\patient_pipeline\utils\run_patient.py:1
# ----> 1 from utils.online_simulation import online_simulation, online_window_simulation_v1
#       2 from utils.preprocessing import load_session_chached, merge_sessions
#       3 from utils.offline_evaluation import compare_auc_single_trial_interval, compute_auc_with_cv
#
# ImportError: cannot import name 'online_window_simulation_v1' from 'utils.online_simulation' (c:\Users\Soz\OneDrive - Radboud Universiteit\Bureaublad\BSc_Thesis\Code\BSc_Thesis_Project\ERP_analysis_code\patient_pipeline\utils\online_simulation.py)

# %%
import line_profiler
# %load_ext line_profiler

def my_function(x):
    e = 0
    for i in range(x):
        e+=i

# Example:
# %lprun -f my_function my_function(500)

# %%
#features_online = load_features_chached_v2(r"B:\_anonymized_data_P01a_P1_S4_anonymized.pkl")
# for i in range(3,18):
#     features = load_features_chached(f"B:\_anonymized_data_P01a_P1_S{i}_anonymized.pkl")

#for i in range(3,14):
#    features = load_features_chached(f"B:\_anonymized_data_P02a_P1_S{i}_anonymized.pkl")

#features_train = load_features_chached_v2(r"B:\_anonymized_data_P01a_P1_S3_anonymized.pkl")

from pathlib import Path
import re

def get_help_path_from_pickle_path(pickle_path):
    """
    Convert a flattened pickle filename like:
        B:\_anonymized_data_P01a_P1_S1_anonymized.pkl
    to the original folder-style path like:
        B:\anonymized_data\P01a\P1_S1\anonymized
    """
    path = Path(pickle_path)
    fname = path.name

    match = re.match(r"_anonymized_data_(P\d+a)_(P\d+_S\d+)_anonymized\.pkl", fname)
    if not match:
        raise ValueError(f"Could not parse patient/session info from: {fname}")

    part1 = match.group(1)  # e.g. P01a
    part2 = match.group(2)  # e.g. P1_S1

    help_path = path.parent / "anonymized_data" / part1 / part2 / "anonymized"
    return str(help_path)
from pathlib import Path
import re

import os

def parse_pickle_path(pickle_path):
    # Extract the full filename without directory
    filename = os.path.basename(pickle_path)
    
    # Regex to extract patient/session info
    match = re.match(r'_anonymized_data_(P\d{2}a)_P(\d+)_S(\d+)_anonymized(.*)\.pkl', filename)
    if not match:
        raise ValueError(f"Invalid filename format: {filename}")
    
    project, patient, session, suffix = match.groups()

    # Construct help_path
    help_path = os.path.join(
        "B:/", "anonymized_data", project, f"P{patient}_S{session}", "anonymized"
    )

    # Extract optional selection and discard_channels from suffix
    selection = None
    discard_channels = False

    if "_dc" in suffix:
        discard_channels = True
        suffix = suffix.replace("_dc", "")  # Remove _dc so it doesn't pollute selection

    # Now match selection without _dc
    sel_match = re.search(r'(6D_\w+)', suffix)
    if sel_match:
        selection = sel_match.group(1)

    return help_path, selection, discard_channels

import glob
import os
from utils.feature_extraction import load_or_extract_markers

# the folder containing the data
data_dir = r"B:\\"  # ends with a backslash or double backslash

# Use glob to find all .pkl files that match your pattern
file_pattern = os.path.join(data_dir, "_anonymized_data*.pkl")
all_pickle_files = glob.glob(file_pattern)

print(f"Found {len(all_pickle_files)} .pkl files.")

# Loop through all files and run function
for pickle_path in all_pickle_files:
    print(pickle_path)
    load_features_chached_v2(pickle_path=pickle_path)
#     print(f"\nProcessing pickle path: {pickle_path}")
#     #"B:\anonymized_data\P01a\P1_S1\anonymized"
#     help_path, selection, discard_channels = parse_pickle_path(pickle_path=pickle_path)
#     print("help_path:",help_path)  # B:\anonymized_data\P01a\P1_S1\anonymized
#     print("selection:",selection)  # 6D_long_350
#     print("dc:",discard_channels)  # True
#     online_trials = load_session_chached((help_path),selection=selection, discard_channels=discard_channels).get('trials')
#     try:
#         markers_info = load_or_extract_markers(pickle_path, online_trials)
#     except Exception as e:
#         print(f"Failed to process {pickle_path}: {e}")
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\_'
# <>:14: SyntaxWarning: invalid escape sequence '\_'
# C:\Users\Soz\AppData\Local\Temp\ipykernel_1396\3759650856.py:14: SyntaxWarning: invalid escape sequence '\_'
#   """
# Found 194 .pkl files.
# B:\_anonymized_data_P01a_P1_S10_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S10_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S10_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S10_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S11_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S11_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S11_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S11_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S12_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S12_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S12_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S12_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S13_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S13_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S13_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S13_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S14_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S14_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S14_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S14_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S15_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S15_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S15_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S15_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S16_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S16_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S16_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S16_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S17_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S17_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S17_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S17_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S1_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P01a_P1_S1_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S1_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S1_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P01a_P1_S2_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P01a_P1_S2_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S2_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S2_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P01a_P1_S3_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S3_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S3_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S3_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S4_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S4_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S4_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S4_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S5_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S5_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S5_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S5_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S6_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S6_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S6_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S6_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S7_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S7_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S7_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S7_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S8_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S8_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S8_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S8_anonymized.pkl
# B:\_anonymized_data_P01a_P1_S9_anonymized.pkl
# Original file:  B:__anonymized_data_P01a_P1_S9_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P01a_P1_S9_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P01a_P1_S9_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S10_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S10_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S10_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S10_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S11_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S11_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S11_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S11_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S12_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S12_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S12_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S12_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S13_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S13_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S13_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S13_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S1_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P02a_P2_S1_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S1_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S1_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P02a_P2_S2_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P02a_P2_S2_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S2_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S2_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P02a_P2_S3_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S3_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S3_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S3_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S4_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S4_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S4_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S4_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S5_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S5_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S5_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S5_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S6_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S6_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S6_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S6_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S7_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S7_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S7_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S7_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S8_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S8_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S8_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S8_anonymized.pkl
# B:\_anonymized_data_P02a_P2_S9_anonymized.pkl
# Original file:  B:__anonymized_data_P02a_P2_S9_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P02a_P2_S9_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P02a_P2_S9_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S10_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S10_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S10_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S10_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S11_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S11_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S11_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S11_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S12_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S12_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S12_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S12_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S13_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S13_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S13_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S13_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S14_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S14_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S14_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S14_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S15_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S15_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S15_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S15_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S16_anonymized.pkl
# Original file:  B:__anonymized_data_P03a_P3_S16_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S16_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S16_anonymized.pkl
# B:\_anonymized_data_P03a_P3_S1_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P03a_P3_S1_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S1_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S1_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P03a_P3_S1_anonymized6D_short_250_dc.pkl
# Original file:  B:__anonymized_data_P03a_P3_S1_anonymized6D_short_250_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S1_anonymized6D_short_250_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S1_anonymized6D_short_250_dc.pkl
# B:\_anonymized_data_P03a_P3_S1_anonymizedHP_short_250_dc.pkl
# Original file:  B:__anonymized_data_P03a_P3_S1_anonymizedHP_short_250_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S1_anonymizedHP_short_250_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S1_anonymizedHP_short_250_dc.pkl
# B:\_anonymized_data_P03a_P3_S2_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P03a_P3_S2_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S2_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S2_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P03a_P3_S2_anonymized6D_short_250_dc.pkl
# Original file:  B:__anonymized_data_P03a_P3_S2_anonymized6D_short_250_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_S2_anonymized6D_short_250_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P03a_P3_S2_anonymized6D_short_250_dc.pkl
# B:\_anonymized_data_P03a_P3_S2_anonymizedHP_short_250_dc.pkl
# Original file:  B:__anonymized_data_P03a_P3_S2_anonymizedHP_short_250_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P03a_P3_
long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S1_anonymizedHP_long_350_dc.pkl
# B:\_anonymized_data_P09a_P9_S2_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P09a_P9_S2_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S2_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S2_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P09a_P9_S2_anonymizedHP_long_350_dc.pkl
# Original file:  B:__anonymized_data_P09a_P9_S2_anonymizedHP_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S2_anonymizedHP_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S2_anonymizedHP_long_350_dc.pkl
# B:\_anonymized_data_P09a_P9_S3_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S3_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S3_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S3_anonymized.pkl
# B:\_anonymized_data_P09a_P9_S4_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S4_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S4_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S4_anonymized.pkl
# B:\_anonymized_data_P09a_P9_S5_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S5_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S5_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S5_anonymized.pkl
# B:\_anonymized_data_P09a_P9_S6_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S6_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S6_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S6_anonymized.pkl
# B:\_anonymized_data_P09a_P9_S7_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S7_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S7_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S7_anonymized.pkl
# B:\_anonymized_data_P09a_P9_S8_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S8_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S8_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S8_anonymized.pkl
# B:\_anonymized_data_P09a_P9_S9_anonymized.pkl
# Original file:  B:__anonymized_data_P09a_P9_S9_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P09a_P9_S9_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P09a_P9_S9_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S10_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S10_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S10_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S10_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S11_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S11_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S11_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S11_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S12_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S12_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S12_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S12_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S13_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S13_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S13_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S13_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S14_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S14_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S14_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S14_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S15_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S15_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S15_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S15_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S1_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P10a_P10_S1_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S1_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S1_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P10a_P10_S2_anonymized6D_long_350_dc.pkl
# Original file:  B:__anonymized_data_P10a_P10_S2_anonymized6D_long_350_dc.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S2_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S2_anonymized6D_long_350_dc.pkl
# B:\_anonymized_data_P10a_P10_S3_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S3_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S3_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S3_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S4_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S4_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S4_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S4_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S5_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S5_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S5_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S5_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S6_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S6_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S6_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S6_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S7_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S7_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S7_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S7_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S8_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S8_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S8_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S8_anonymized.pkl
# B:\_anonymized_data_P10a_P10_S9_anonymized.pkl
# Original file:  B:__anonymized_data_P10a_P10_S9_anonymized.pkl
# Corresponding .pkl file:  B:\features_v2\features_v2__anonymized_data_P10a_P10_S9_anonymized.pkl
# A .pkl file already exists. Loading the data from B:\features_v2\features_v2__anonymized_data_P10a_P10_S9_anonymized.pkl

# %%
# features_s1 =load_features_chached(r"B:_anonymized_data_P01a_P1_S1_anonymized6D_long_350_dc.pkl")
# print(features_s1.keys())

# features_s2 =load_features_chached(r"B:_anonymized_data_P01a_P1_S2_anonymized6D_long_350_dc.pkl")
# print(features_s2.keys())

# features_merged = merge_features(features_s1, features_s2)

# %%
# Run Transfer on all
from utils.db import patients_db

print(patients_db)
for id in patients_db:
    if id==8:
        info = patients_db.get(id)
        patient = info.get('patient_nr')
        last_session = info.get('last_session')
        calibration_selection = info.get('selection')

        print("patient: ", patient)
        print("last session", last_session)
        print("calibration_selection", calibration_selection)

        performances = run_patient_online_sessions(patient, last_session, calibration_selection)
        with open(f"p{patient}_performances_v1.pkl", 'wb') as f: 
            pickle.dump(performances, f)

# %%
# Run static on all

from utils.static_protocol import static_protocol
from utils.run_patient import run_patient_online_sessions_static

print(static_protocol)
for id in static_protocol:
    info = static_protocol.get(id)
    patient = info.get('patient_nr')
    last_session = info.get('last_session')
    calibration_selection = info.get('selection')
    changing_conditions = info.get('changing_condition')
    if changing_conditions:
        starter_conditions = info.get('changing_starter_sessions')
    else:
        starter_conditions = None
        
    print("patient: ", patient)
    print("last session: ", last_session)
    print("calibration_selection: ", calibration_selection)
    print("changing conditions: ", changing_conditions)

    performances = run_patient_online_sessions_static(patient, last_session, calibration_selection, starter_conditions)
    with open(f"p{patient}_performances_static_v1.pkl", 'wb') as f: 
        pickle.dump(performances, f)

# %%
# Code to concatenate all trails of patient 9 (pilot)
from utils.feature_extraction import merge_features

patient_string = "09"
patient = 9
last_session = 18
calibration_selection = "6D_long_350"
calibration_selection_dc =  f"{calibration_selection}_dc"


data_path_s1 = f"B:/anonymized_data/P{patient_string}a/P{patient}_S1/anonymized"
data_path_s2 = f"B:/anonymized_data/P{patient_string}a/P{patient}_S2/anonymized"
data_s1 = load_session_chached(data_path_s1, selection = calibration_selection, discard_channels=True)
data_s2 = load_session_chached(data_path_s2, selection = calibration_selection, discard_channels=True)
data_train = merge_sessions(data_s1, data_s2)
data_merged = data_train

# features_s1 = load_features_chached(f"B:_anonymized_data_P{patient_string}a_P{patient}_S1_anonymized{calibration_selection_dc}.pkl")
# features_s2 = load_features_chached(f"B:_anonymized_data_P{patient_string}a_P{patient}_S2_anonymized{calibration_selection_dc}.pkl")
# features_train = merge_features(features_s1, features_s2)
# features_merged = features_train

for i in range(3,last_session):
    data_train = data_merged
    #features_train = features_merged
    data_next =load_session_chached(f"B:/anonymized_data/P{patient_string}a/P{patient}_S{i}/anonymized")
    #features_next = load_features_chached(f"B:_anonymized_data_P{patient_string}a_P{patient}_S{i}_anonymized.pkl")
    data_merged = merge_sessions(data_train, data_next)
    #features_merged = merge_features(features_train, features_next)

del data_train
del data_s1
del data_s2
del data_path_s1
del data_path_s2
del data_next
del calibration_selection
del calibration_selection_dc
del patient
del last_session
del patient_string
# Out:
# Loading file:  B:_anonymized_data_P09a_P9_S1_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S1_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S1_anonymized6D_long_350_dc.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S2_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S2_anonymized6D_long_350_dc.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S2_anonymized6D_long_350_dc.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S3_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S3_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S3_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S4_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S4_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S4_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S5_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S5_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S5_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S6_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S6_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S6_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S7_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S7_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S7_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S8_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S8_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S8_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S9_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S9_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S9_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S10_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S10_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S10_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S11_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S11_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S11_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S12_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S12_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S12_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S13_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S13_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S13_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S14_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S14_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S14_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S15_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S15_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S15_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S16_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S16_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S16_anonymized.pkl
# Loading file:  B:_anonymized_data_P09a_P9_S17_anonymized
# Corresponding .pkl file:  B:_anonymized_data_P09a_P9_S17_anonymized.pkl
# A .pkl file already exists. Loading the data from B:_anonymized_data_P09a_P9_S17_anonymized.pkl

# %%
print("Data keys: ",data_merged.keys())
# for f in data_merged.get('filenames'):
#     print(f)
#print(data_merged.get('preprocessing'))
# print(f"Trials total: {len(data_merged.get('trials'))}")
# print(f"Iterations total: {len(data_merged.get('iterations'))}")
# print(f"Epochs total: {len(data_merged.get('epochs'))}")
# print(f"Preprocessing: {(data_merged.get('preprocessing'))}")
# print(f"Timestamp: {(data_merged.get('timestamp'))}")
# print(f"Loaded filenames: ")
# for f in data_merged.get('filenames'):
#     print(f)

print((data_merged.get('epochs')[:6]))
print((data_merged.get('iterations')[0]))
print((data_merged.get('trials')[0][0]))
# Out:
# Data keys:  dict_keys(['trials', 'iterations', 'epochs', 'filenames', 'preprocessing', 'timestamp'])
# <EpochsArray | 6 events (all good), -0.2 – 1 s (baseline off), ~229 KiB, data loaded,
#  'Word_6/Target': 1
#  'Word_1/NonTarget': 1
#  'Word_2/NonTarget': 1
#  'Word_3/NonTarget': 1
#  'Word_4/NonTarget': 1
#  'Word_5/NonTarget': 1>
# <EpochsArray | 6 events (all good), -0.2 – 1 s (baseline off), ~229 KiB, data loaded,
#  'Word_6/Target': 1
#  'Word_1/NonTarget': 1
#  'Word_2/NonTarget': 1
#  'Word_3/NonTarget': 1
#  'Word_4/NonTarget': 1
#  'Word_5/NonTarget': 1>
# <EpochsArray | 6 events (all good), -0.2 – 1 s (baseline off), ~229 KiB, data loaded,
#  'Word_6/Target': 1
#  'Word_1/NonTarget': 1
#  'Word_2/NonTarget': 1
#  'Word_3/NonTarget': 1
#  'Word_4/NonTarget': 1
#  'Word_5/NonTarget': 1>
